66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}</td><td>78</td><td>true</td><td>Solo</td></tr><tr><td>55S2PQgSMYAhgoTCcGCDfw</td><td>Youngblood</td><td>('Youngblood', '5 Seconds Of Summer')</td><td>{'5Rl15oVamLq7FbSb0NNBNy': '5 Seconds of Summer'}</td><td>77</td><td>false</td><td>Solo</td></tr><tr><td>7dt6x5M1jzdTEt8oCbisTK</td><td>Better Now</td><td>('Better Now', 'Post Malone')</td><td>{'246dkjvS1zLTtiykXe5h60': 'Post Malone'}</td><td>86</td><td>true</td><td>Solo</td></tr><tr><td>285pBltuF7vW8TeWk8hdRR</td><td>Lucid Dreams</td><td>('Lucid Dreams', 'Juice WRLD')</td><td>{'4MCBfE4596Uoi2O4DtmEMz': 'Juice WRLD'}</td><td>85</td><td>true</td><td>Solo</td></tr><tr><td>39LmTF9RgyakzSYX8txrow</td><td>imagine</td><td>('Imagine', 'Ariana Grande')</td><td>{'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}</td><td>76</td><td>true</td><td>Solo</td></tr><tr><td>2FRnf9qhLbvw8fu4IBXx78</td><td>Last Christmas</td><td>('Last Christmas', 'Wham!')</td><td>{'5lpH0xAS4fVfLkACg9DAuM': 'Wham!'}</td><td>55</td><td>false</td><td>Solo</td></tr><tr><td>1dtIaSly ...

# %%
New spark session
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('ProblemApp').getOrCreate()

# %%
# %sql
SELECT song_name, popularity, release_date
FROM Songs_df
JOIN tracks_df ON (songs_df.song_id == tracks_df.song_id)
ORDER BY popularity DESC

# %%
joined_df = songs_df.join(tracks_df, (songs_df.song_id == tracks_df.song_id), "inner").select('song_name','popularity', 'release_date').orderBy('popularity', ascending=False)

# %%
joined_df = songs_df.join(tracks_df, (songs_df.song_id == tracks_df.song_id), "inner").select('song_name', 'popularity', 'release_date').orderBy('popularity', ascending=False)

# %%
joined_df.show()
# Out:
# +--------------------+----------+-------------------+
# |           song_name|popularity|       release_date|
# +--------------------+----------+-------------------+
# |Sunflower - Spide...|        92|2018-12-14 00:00:00|
# |when the party's ...|        87|2019-03-29 00:00:00|
# |          Without Me|        87|2018-10-04 00:00:00|
# |       thank u, next|        86|2019-02-08 00:00:00|
# |          Better Now|        86|2018-04-27 00:00:00|
# |    Sweet but Psycho|        86|2018-08-17 00:00:00|
# |          High Hopes|        86|2018-06-22 00:00:00|
# |            Believer|        86|2017-06-23 00:00:00|
# |                Talk|        85|2019-04-05 00:00:00|
# |        Lucid Dreams|        85|2018-12-10 00:00:00|
# |          SICKO MODE|        85|2018-08-03 00:00:00|
# |             Perfect|        85|2017-03-03 00:00:00|
# |           Moonlight|        84|2018-03-16 00:00:00|
# |             Thunder|        84|2017-06-23 00:00:00|
# |                SAD!|        84|2018-03-16 00:00:00|
# |        Shape of You|        84|2017-03-03 00:00:00|
# |          The Middle|        83|2018-01-23 00:00:00|
# |          Be Alright|        83|2018-06-29 00:00:00|
# |          God's Plan|        83|2018-06-29 00:00:00|
# |you should see me...|        83|2019-03-29 00:00:00|
# +--------------------+----------+-------------------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from collections import namedtuple

# %%
class music_table:
    
    def __init__(self, appname, filetype, location, delimeter):
        self.spark = SparkSession.builder.appName(appname).getOrCreate()
        self.filetype = filetype
        self.location = location
        self.delimeter = delimeter
    
    def load_music_table(self):
        df = self.spark.read.format(self.filetype).option("inferSchema", "true").option("header", "true").option("sep", self.delimeter).load(self.location)
        return df
    
    def show_music_table(self):
        df.show()
    
    def printschema(self):
        df.printSchema()
        
    def get_music_table(self):
        return df

# %%
tracks_df = music_table(appname='name',location = "/FileStore/tables/tracks.csv", filetype = 'csv', delimeter = "	")

# %%
tracks_df.load_music_table()
# Out:
# Out[71]: DataFrame[song_id: string, album_id: string, track_number: int, release_date: timestamp, release_date_precision: string]

# %%
tracks_df.show_music_table()
# Out:
# +--------------------+--------------------+------------+-------------------+----------------------+
# |             song_id|            album_id|track_number|       release_date|release_date_precision|
# +--------------------+--------------------+------------+-------------------+----------------------+
# |3e9HZxeyfWwjeyPAM...|2fYhqwDWXjbpjaIJP...|          11|2019-02-08 00:00:00|                   day|
# |5p7ujcrUXASCNwRaW...|0zzrCTzvL4ZmR42xF...|           1|2018-10-04 00:00:00|                   day|
# |2xLMifQCjDGFmkHkp...|41GuZcammIkupMPKH...|           3|2018-08-03 00:00:00|                   day|
# |3KkXRkHbMCARz0aVf...|35s58BRTGAEWztPo9...|           2|2018-12-14 00:00:00|                   day|
# |1rqqCSm0Qe4I9rUvW...|6ApYSpXF8GxZAgBTH...|           4|2018-06-22 00:00:00|                   day|
# |0bYg9bo50gSsH3LtX...|61ulfFSmmxMhc2wCd...|           2|1994-11-01 00:00:00|                   day|
# |5hslUAKq9I9CG2bAu...|4dcJHxlOJwtyypL7s...|           4|1963-01-01 00:00:00|                  year|
# |2EjXfH91m7f8HiJN1...|34wa3zf2prXFMk47t...|           1|1964-10-19 00:00:00|                   day|
# |0MMSmg7zyo6pOKZrf...|2qk6WsJYyUWKsIeAE...|          22|2015-10-28 00:00:00|                   day|
# |6Z924AupOiJLdnAKH...|2xUZadTnycgVALCJM...|          12|1983-01-01 00:00:00|                   day|
# |1xzBco0xcoJEDXktl...|15Id9Jrqab8IwHFir...|           9|2018-10-05 00:00:00|                   day|
# |4PS1e8f2LvuTFgUs1...|6vBGI5522jvPi0ZZu...|           1|1962-01-01 00:00:00|                  year|
# |4OafepJy2teCjYJbv...|3tx8gQqWbGwqIGZHq...|           9|2018-08-17 00:00:00|                   day|
# |55S2PQgSMYAhgoTCc...|16Qs4jnIyXe7jprnM...|           1|2018-04-12 00:00:00|                   day|
# |7dt6x5M1jzdTEt8oC...|6trNtQUgC8cgbWcqo...|           9|2018-04-27 00:00:00|                   day|
# |285pBltuF7vW8TeWk...|6tkjU4Umpo79wwkgP...|           3|2018-12-10 00:00:00|                   day|
# |39LmTF9RgyakzSYX8...|2fYhqwDWXjbpjaIJP...|           1|2019-02-08 00:00:00|                   day|
# |2FRnf9qhLbvw8fu4I...|6egzU9NKfora01qaN...|           1|1984-01-01 00:00:00|                  year|
# |1dtIaSlyrLI04sqYa...|3BPDSjoJlho8oiUPU...|           2|1947-01-01 00:00:00|                  year|
# |6CTWathupIiDs7U4I...|67ErXRS9s9pVG8JmF...|          13|2018-10-12 00:00:00|                   day|
# +--------------------+--------------------+------------+-------------------+----------------------+
# only showing top 20 rows

# %%
tracks_df.printschema()
# Out:
# root
#  |-- song_id: string (nullable = true)
#  |-- album_id: string (nullable = true)
#  |-- track_number: integer (nullable = true)
#  |-- release_date: timestamp (nullable = true)
#  |-- release_date_precision: string (nullable = true)

# %%
tracks_df.get_music_table().show()
# Out:
# +--------------------+--------------------+------------+-------------------+----------------------+
# |             song_id|            album_id|track_number|       release_date|release_date_precision|
# +--------------------+--------------------+------------+-------------------+----------------------+
# |3e9HZxeyfWwjeyPAM...|2fYhqwDWXjbpjaIJP...|          11|2019-02-08 00:00:00|                   day|
# |5p7ujcrUXASCNwRaW...|0zzrCTzvL4ZmR42xF...|           1|2018-10-04 00:00:00|                   day|
# |2xLMifQCjDGFmkHkp...|41GuZcammIkupMPKH...|           3|2018-08-03 00:00:00|                   day|
# |3KkXRkHbMCARz0aVf...|35s58BRTGAEWztPo9...|           2|2018-12-14 00:00:00|                   day|
# |1rqqCSm0Qe4I9rUvW...|6ApYSpXF8GxZAgBTH...|           4|2018-06-22 00:00:00|                   day|
# |0bYg9bo50gSsH3LtX...|61ulfFSmmxMhc2wCd...|           2|1994-11-01 00:00:00|                   day|
# |5hslUAKq9I9CG2bAu...|4dcJHxlOJwtyypL7s...|           4|1963-01-01 00:00:00|                  year|
# |2EjXfH91m7f8HiJN1...|34wa3zf2prXFMk47t...|           1|1964-10-19 00:00:00|                   day|
# |0MMSmg7zyo6pOKZrf...|2qk6WsJYyUWKsIeAE...|          22|2015-10-28 00:00:00|                   day|
# |6Z924AupOiJLdnAKH...|2xUZadTnycgVALCJM...|          12|1983-01-01 00:00:00|                   day|
# |1xzBco0xcoJEDXktl...|15Id9Jrqab8IwHFir...|           9|2018-10-05 00:00:00|                   day|
# |4PS1e8f2LvuTFgUs1...|6vBGI5522jvPi0ZZu...|           1|1962-01-01 00:00:00|                  year|
# |4OafepJy2teCjYJbv...|3tx8gQqWbGwqIGZHq...|           9|2018-08-17 00:00:00|                   day|
# |55S2PQgSMYAhgoTCc...|16Qs4jnIyXe7jprnM...|           1|2018-04-12 00:00:00|                   day|
# |7dt6x5M1jzdTEt8oC...|6trNtQUgC8cgbWcqo...|           9|2018-04-27 00:00:00|                   day|
# |285pBltuF7vW8TeWk...|6tkjU4Umpo79wwkgP...|           3|2018-12-10 00:00:00|                   day|
# |39LmTF9RgyakzSYX8...|2fYhqwDWXjbpjaIJP...|           1|2019-02-08 00:00:00|                   day|
# |2FRnf9qhLbvw8fu4I...|6egzU9NKfora01qaN...|           1|1984-01-01 00:00:00|                  year|
# |1dtIaSlyrLI04sqYa...|3BPDSjoJlho8oiUPU...|           2|1947-01-01 00:00:00|                  year|
# |6CTWathupIiDs7U4I...|67ErXRS9s9pVG8JmF...|          13|2018-10-12 00:00:00|                   day|
# +--------------------+--------------------+------------+-------------------+----------------------+
# only showing top 20 rows
